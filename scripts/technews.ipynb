# %%
import json
import time
from datetime import datetime
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from api_util import read_token, BASE_URL, get_headers
import requests

def _make_get_request(endpoint, params=None, quiet=None):
    """共用的 HTTP GET 請求處理函數"""
    try:
        response = requests.get(f"{BASE_URL}/{endpoint}", headers=get_headers(read_token()), params=params)
        response.raise_for_status()
        result = response.json()
        if not quiet: 
            print(result)
        return result
    except requests.exceptions.RequestException as err:
        print(f"Request failed: {err}")
        return None
    
def _make_post_request(endpoint, data, quiet=None):
	try:
		response = requests.post(f"{BASE_URL}/{endpoint}", headers=get_headers(read_token()), json=data)
		response.raise_for_status()
		result = response.json()
		if not quiet: 
			print(result)
		return result
	except requests.exceptions.RequestException as err:
		print(f"Request failed: {err}")
		return None
    
def get_all_technews (page, size, keyword=None):
	res =  _make_get_request('technews',  params={
		'page': page,
		'size': size,
        'keyword': keyword
	})
	return res.get('data')[::-1]
    
def create_one_company_news (params):
    res = _make_post_request('/company-news', params)
    return res
    
def get_all_company_news (page, size):
	res =  _make_get_request('company-news', {
		'page': page,
		'size': size
	})
	return res.get('data')[::-1]
    
def get_all_company_news_by_keyword (keyword, page=1, size=10):
	res =  _make_get_request('/company-news/search', {
		'page': page,
		'size': size,
		'keyword': keyword
	})
	return res.get('data')

def print_news(news):
	for item in news:
		id = item.get('id', '--')
		title = item.get('title', '--')
		print(f"{id} : {title} \n")

# %%
keyword = 'ai'

news = get_all_technews(2, 10, keyword=keyword)

print_news(news)
# Out:
# {'code': 200, 'success': True, 'data': [{'id': 137610, 'title': 'NASA 與 Google 攜手打造 AI 醫療助理，確保太空人健康上火星', 'release_time': '2025-08-11T04:45:00.000Z', 'publisher': 'TechNews 編輯台', 'web_url': 'https://technews.tw/2025/08/11/nasa-and-google-launch-space-doctor-ai-assistant/', 'createdAt': '2025-08-12T09:30:00.000Z', 'updatedAt': '2025-08-12T09:30:00.000Z'}, {'id': 137601, 'title': '新加坡總理談 AI，擁抱它但不應太躁進', 'release_time': '2025-08-11T03:15:00.000Z', 'publisher': '黃 嬿', 'web_url': 'https://technews.tw/2025/08/11/the-attitude-of-ai-policy/', 'createdAt': '2025-08-12T09:30:00.000Z', 'updatedAt': '2025-08-12T09:30:00.000Z'}, {'id': 137609, 'title': 'AI 崛起、川普政府削減合約預算  顧問業有壓力', 'release_time': '2025-08-11T04:30:00.000Z', 'publisher': 'MoneyDJ', 'web_url': 'https://technews.tw/2025/08/11/the-rise-of-ai-puts-pressure-on-the-consulting-industry/', 'createdAt': '2025-08-12T09:30:00.000Z', 'updatedAt': '2025-08-12T09:30:00.000Z'}, {'id': 137604, 'title': '創新 ASIC 設計！揚智攜手 Ceva 以可擴展邊緣 AI 導入新世代影音平台', 'release_time': '2025-08-11T03:34:00.000Z', 'publisher': '姚 惠茹', 'web_url': 'https://finance.technews.tw/2025/08/11/neupro-nano/', 'createdAt': '2025-08-12T09:30:00.000Z', 'updatedAt': '2025-08-12T09:30:00.000Z'}, {'id': 137606, 'title': 'AI 人才流失、Siri 新版延後至 2026，蘋果想靠收購翻身？', 'release_time': '2025-08-11T04:00:00.000Z', 'publisher': 'TechNews 編輯台', 'web_url': 'https://technews.tw/2025/08/11/apples-shopping-list-and-how-to-get-a-job-offer-from-meta/', 'createdAt': '2025-08-12T09:30:00.000Z', 'updatedAt': '2025-08-12T09:30:00.000Z'}, {'id': 137582, 'title': '曾是開源聖地，GitHub 整合微軟 CoreAI 團隊意味著什麼？', 'release_time': '2025-08-12T02:45:00.000Z', 'publisher': 'TechNews 編輯台', 'web_url': 'https://finance.technews.tw/2025/08/12/github-coreai/', 'createdAt': '2025-08-12T06:30:42.000Z', 'updatedAt': '2025-08-12T06:30:42.000Z'}, {'id': 137572, 'title': '自研 AI 晶片夢碎？蘋果、亞馬遜、特斯拉接連敗給輝達', 'release_time': '2025-08-12T01:45:00.000Z', 'publisher': 'TechNews 編輯台', 'web_url': 'https://technews.tw/2025/08/12/nvidia-amd-amazon-apple-tesla/', 'createdAt': '2025-08-12T06:30:42.000Z', 'updatedAt': '2025-08-12T06:30:42.000Z'}, {'id': 137573, 'title': 'iOS 26 測試版暗示 AirPods 將加入即時翻譯手勢功能', 'release_time': '2025-08-12T01:55:00.000Z', 'publisher': '邱 倢芯', 'web_url': 'https://ccc.technews.tw/2025/08/12/ios-26-airpods-live-translation/', 'createdAt': '2025-08-12T06:30:42.000Z', 'updatedAt': '2025-08-12T06:30:42.000Z'}, {'id': 137562, 'title': '曾是開源聖地，GitHub 整合微軟 CoreAI 團隊意味著什麼？', 'release_time': '2025-08-12T02:45:00.000Z', 'publisher': 'TechNews 編輯台', 'web_url': 'https://finance.technews.tw/2025/08/12/github-coreai/', 'createdAt': '2025-08-12T06:30:32.000Z', 'updatedAt': '2025-08-12T06:30:32.000Z'}, {'id': 137541, 'title': '4 兆美元 AI 帝國繼承之戰！黃仁勳「王儲」曝光：長公主比他還狠，太子低調進入權力核心', 'release_time': '2025-08-12T00:10:00.000Z', 'publisher': '愛范兒', 'web_url': 'https://finance.technews.tw/2025/08/12/jensen-huang-son-and-daughter/', 'createdAt': '2025-08-12T06:30:21.000Z', 'updatedAt': '2025-08-12T06:30:21.000Z'}], 'message': '成功'}
# 137541 : 4 兆美元 AI 帝國繼承之戰！黃仁勳「王儲」曝光：長公主比他還狠，太子低調進入權力核心
#
# 137562 : 曾是開源聖地，GitHub 整合微軟 CoreAI 團隊意味著什麼？
#
# 137573 : iOS 26 測試版暗示 AirPods 將加入即時翻譯手勢功能
#
# 137572 : 自研 AI 晶片夢碎？蘋果、亞馬遜、特斯拉接連敗給輝達
#
# 137582 : 曾是開源聖地，GitHub 整合微軟 CoreAI 團隊意味著什麼？
#
# 137606 : AI 人才流失、Siri 新版延後至 2026，蘋果想靠收購翻身？
#
# 137604 : 創新 ASIC 設計！揚智攜手 Ceva 以可擴展邊緣 AI 導入新世代影音平台
#
# 137609 : AI 崛起、川普政府削減合約預算  顧問業有壓力
#
# 137601 : 新加坡總理談 AI，擁抱它但不應太躁進
#
# 137610 : NASA 與 Google 攜手打造 AI 醫療助理，確保太空人健康上火星

# %%
all_news = get_all_technews(page=1, size=15)
print_news(all_news)
# Out:
# {'code': 200, 'success': True, 'data': [{'id': 137679, 'title': '盧超群：台灣半導體貢獻多，受壓抑是全世界巨大挫折', 'release_time': '2025-08-12T07:50:00.000Z', 'publisher': '中央社', 'web_url': 'https://technews.tw/2025/08/12/lu-chao-chun-sees-taiwan-semiconductor-suppression-as-major-setback/', 'createdAt': '2025-08-12T09:30:51.000Z', 'updatedAt': '2025-08-12T09:30:51.000Z'}, {'id': 137678, 'title': '中國點名 H20 有風險，呼籲企業停止採購', 'release_time': '2025-08-12T07:45:00.000Z', 'publisher': '蘇 子芸', 'web_url': 'https://technews.tw/2025/08/12/china-urges-firms-not-to-use-nv-h20/', 'createdAt': '2025-08-12T09:30:51.000Z', 'updatedAt': '2025-08-12T09:30:51.000Z'}, {'id': 137688, 'title': '美光調升財測營收之際，中國市場卻傳來裁員消息', 'release_time': '2025-08-12T09:10:00.000Z', 'publisher': 'Atkinson', 'web_url': 'https://finance.technews.tw/2025/08/12/micron-china-reports-layoffs/', 'createdAt': '2025-08-12T09:30:51.000Z', 'updatedAt': '2025-08-12T09:30:51.000Z'}, {'id': 137676, 'title': '川普考慮大麻改列低風險藥物  美大麻股集體暴漲', 'release_time': '2025-08-12T07:30:00.000Z', 'publisher': 'MoneyDJ', 'web_url': 'https://finance.technews.tw/2025/08/12/trump-weighs-downgrading-marijuana-regulation-cannabis-stocks-soar/', 'createdAt': '2025-08-12T09:30:51.000Z', 'updatedAt': '2025-08-12T09:30:51.000Z'}, {'id': 137685, 'title': '匯損衝擊中探針第二季虧 0.71 元！美系智慧眼鏡、無人機大單入袋', 'release_time': '2025-08-12T08:42:00.000Z', 'publisher': '姚 惠茹', 'web_url': 'https://finance.technews.tw/2025/08/12/american-smart-glasses/', 'createdAt': '2025-08-12T09:30:51.000Z', 'updatedAt': '2025-08-12T09:30:51.000Z'}, {'id': 137690, 'title': '連賢明：台積電非無敵星星，談判時同張牌不能打了又打', 'release_time': '2025-08-12T09:15:00.000Z', 'publisher': '中央社', 'web_url': 'https://finance.technews.tw/2025/08/12/tsmc-is-not-an-invincible-star/', 'createdAt': '2025-08-12T09:30:51.000Z', 'updatedAt': '2025-08-12T09:30:51.000Z'}, {'id': 137686, 'title': '緯創捐百萬小時 GPU 算力，林憲銘：鼓勵台灣運用 AI', 'release_time': '2025-08-12T08:45:00.000Z', 'publisher': '中央社', 'web_url': 'https://technews.tw/2025/08/12/wistron-donates-million-gpu-hours-to-encourage-taiwan-ai-use/', 'createdAt': '2025-08-12T09:30:51.000Z', 'updatedAt': '2025-08-12T09:30:51.000Z'}, {'id': 137677, 'title': '海外擴大產能！仁寶再砸 90 億投資美國、英業達 47 億擴建泰國廠', 'release_time': '2025-08-12T07:43:00.000Z', 'publisher': '姚 惠茹', 'web_url': 'https://finance.technews.tw/2025/08/12/computer-shipments/', 'createdAt': '2025-08-12T09:30:51.000Z', 'updatedAt': '2025-08-12T09:30:51.000Z'}, {'id': 137680, 'title': '量子計算新突破：IBM 與 Google 引領量子電腦商業化時代', 'release_time': '2025-08-12T08:00:00.000Z', 'publisher': 'TechNews 編輯台', 'web_url': 'https://technews.tw/2025/08/12/google-and-ibm-believe-first-workable-quantum-computer-is-in-sight/', 'createdAt': '2025-08-12T09:30:51.000Z', 'updatedAt': '2025-08-12T09:30:51.000Z'}, {'id': 137681, 'title': '趨勢科技警告：數以千計 AI 伺服器正暴露在網路上', 'release_time': '2025-08-12T08:07:00.000Z', 'publisher': '邱 倢芯', 'web_url': 'https://infosecu.technews.tw/2025/08/12/ai-server-security/', 'createdAt': '2025-08-12T09:30:51.000Z', 'updatedAt': '2025-08-12T09:30:51.000Z'}, {'id': 137683, 'title': '臻鼎因應高階 AI 訂單需求明顯成長！沈慶芳：這兩年資本支出達 300 億', 'release_time': '2025-08-12T08:22:00.000Z', 'publisher': '姚 惠茹', 'web_url': 'https://finance.technews.tw/2025/08/12/abf-carrier-board/', 'createdAt': '2025-08-12T09:30:51.000Z', 'updatedAt': '2025-08-12T09:30:51.000Z'}, {'id': 137689, 'title': '未實現匯損衝擊！智崴第二季獲無人機 2,400 萬補助仍虧損 3.36 元', 'release_time': '2025-08-12T09:10:00.000Z', 'publisher': '姚 惠茹', 'web_url': 'https://finance.technews.tw/2025/08/12/a-enterprise-innovation/', 'createdAt': '2025-08-12T09:30:51.000Z', 'updatedAt': '2025-08-12T09:30:51.000Z'}, {'id': 137687, 'title': '中國商務部：17 家美企不可靠實體清單繼續暫停', 'release_time': '2025-08-12T09:00:00.000Z', 'publisher': '中央社', 'web_url': 'https://technews.tw/2025/08/12/17-us-companies-remain-suspended-from-the-unreliable-entity-list/', 'createdAt': '2025-08-12T09:30:51.000Z', 'updatedAt': '2025-08-12T09:30:51.000Z'}, {'id': 137684, 'title': '增加台灣談判籌碼，連賢明建議用半導體助美國 AI 獲勝', 'release_time': '2025-08-12T08:30:00.000Z', 'publish ...
# 137682 : 早期宇宙驚現「葡萄串」星系，含至少 15 個大質量恆星形成團塊
#
# 137684 : 增加台灣談判籌碼，連賢明建議用半導體助美國 AI 獲勝
#
# 137687 : 中國商務部：17 家美企不可靠實體清單繼續暫停
#
# 137689 : 未實現匯損衝擊！智崴第二季獲無人機 2,400 萬補助仍虧損 3.36 元
#
# 137683 : 臻鼎因應高階 AI 訂單需求明顯成長！沈慶芳：這兩年資本支出達 300 億
#
# 137681 : 趨勢科技警告：數以千計 AI 伺服器正暴露在網路上
#
# 137680 : 量子計算新突破：IBM 與 Google 引領量子電腦商業化時代
#
# 137677 : 海外擴大產能！仁寶再砸 90 億投資美國、英業達 47 億擴建泰國廠
#
# 137686 : 緯創捐百萬小時 GPU 算力，林憲銘：鼓勵台灣運用 AI
#
# 137690 : 連賢明：台積電非無敵星星，談判時同張牌不能打了又打
#
# 137685 : 匯損衝擊中探針第二季虧 0.71 元！美系智慧眼鏡、無人機大單入袋
#
# 137676 : 川普考慮大麻改列低風險藥物  美大麻股集體暴漲
#
# 137688 : 美光調升財測營收之際，中國市場卻傳來裁員消息
#
# 137678 : 中國點名 H20 有風險，呼籲企業停止採購
#
# 137679 : 盧超群：台灣半導體貢獻多，受壓抑是全世界巨大挫折

# %%
all_news = get_all_company_news(page=1, size=5)

print_news(all_news)
# Out:
# {'code': 200, 'success': True, 'data': [{'id': 4950, 'title': 'Analyst who nailed Teslas collapse has a new prediction as Musk turns bearish', 'company_id': 117, 'release_time': '2025-06-06T03:19:00.000Z', 'publisher': 'TheStreet', 'web_url': 'https://finance.yahoo.com/m/6623c151-278e-35b0-9419-e243a29d2f9d/analyst-who-nailed-tesla%E2%80%99s.html', 'createdAt': '2025-06-06T03:32:51.000Z', 'updatedAt': '2025-06-06T03:32:51.000Z', 'Company': {'name': 'Tesla, Inc.'}}, {'id': 4952, 'title': 'Tesla stock slips, Gucci parent looks to sell NY property', 'company_id': 117, 'release_time': '2025-06-06T03:13:00.000Z', 'publisher': 'Yahoo Finance Video', 'web_url': 'https://finance.yahoo.com/video/tesla-stock-slips-gucci-parent-151336912.html', 'createdAt': '2025-06-06T03:32:51.000Z', 'updatedAt': '2025-06-06T03:32:51.000Z', 'Company': {'name': 'Tesla, Inc.'}}, {'id': 4949, 'title': 'Why Is Rivian Automotive (RIVN) Up 10.1% Since Last Earnings Report?', 'company_id': 117, 'release_time': '2025-06-06T03:31:00.000Z', 'publisher': 'Zacks', 'web_url': '/news/74536/why-is-rivian-automotive-rivn-up-101-since-last-earnings-report', 'createdAt': '2025-06-06T03:32:51.000Z', 'updatedAt': '2025-06-06T03:32:51.000Z', 'Company': {'name': 'Tesla, Inc.'}}, {'id': 4953, 'title': "Tesla Robotaxi Service Makes This Firm 'Aggressive Buyers' of Uber Stock", 'company_id': 117, 'release_time': '2025-06-06T03:05:00.000Z', 'publisher': 'Barrons.com', 'web_url': 'https://www.barrons.com/articles/tesla-robotaxi-uber-stock-415b1a91?mod=bar_FV', 'createdAt': '2025-06-06T03:32:51.000Z', 'updatedAt': '2025-06-06T03:32:51.000Z', 'Company': {'name': 'Tesla, Inc.'}}, {'id': 4951, 'title': 'Trump Gets His Call With Xi. The Two Sides Agreed to Keep Talking.', 'company_id': 117, 'release_time': '2025-06-06T03:17:00.000Z', 'publisher': 'Barrons.com', 'web_url': 'https://finance.yahoo.com/m/9164669b-8ecd-38e1-af7c-9cbe6615dc8d/trump-gets-his-call-with-xi..html', 'createdAt': '2025-06-06T03:32:51.000Z', 'updatedAt': '2025-06-06T03:32:51.000Z', 'Company': {'name': 'Tesla, Inc.'}}], 'message': '成功'}
# 4951 : Trump Gets His Call With Xi. The Two Sides Agreed to Keep Talking.
#
# 4953 : Tesla Robotaxi Service Makes This Firm 'Aggressive Buyers' of Uber Stock
#
# 4949 : Why Is Rivian Automotive (RIVN) Up 10.1% Since Last Earnings Report?
#
# 4952 : Tesla stock slips, Gucci parent looks to sell NY property
#
# 4950 : Analyst who nailed Teslas collapse has a new prediction as Musk turns bearish

# %%
keyword = 'ai'
search_news = get_all_company_news_by_keyword(page=1, size=5, keyword=keyword)

print_news(search_news)

# %%
symbol = 'tsla'

# %%
from bs4 import BeautifulSoup
from datetime import datetime, timezone

with open('index.html', 'r', encoding='utf-8') as file:
	html_content = file.read()

soup = BeautifulSoup(html_content, 'html.parser')

news = []

for row in soup.find_all('tr', class_='cursor-pointer has-label'):
	time_cell = row.find('td', align='right')
	time_text = time_cell.get_text(strip=True).replace('Today', '')

	if 'Today' in time_text:
		time_text = time_text.replace('Today', '')
		now = datetime.now(timezone.utc)
		date_str = now.date().isoformat()
	else:
		now = datetime.now(timezone.utc)
		date_str = now.date().isoformat()

	try:
		time_obj = datetime.strptime(time_text, '%I:%M%p')
		time_24hr = time_obj.strftime('%H:%M:%S')
	except ValueError:
		# 如果时间格式无法解析，使用默认时间
		time_24hr = '00:00:00'
		
	# 创建 MySQL 支持的时间字符串
	release_time = f"{date_str} {time_24hr}"

	link = row.find('a', class_='tab-link-news')
	title = link.get_text(strip=True)
	web_url = link['href']

	publisher = row.find('span').get_text(strip=True).strip('()')

	news_item = {
        "title": title,
        "symbol": symbol.upper(),
        "release_time": release_time,
        "publisher": publisher,
        "web_url": web_url
    }

	news.append(news_item)

print(json.dumps(news[0:2], indent=4))

# %%
from time import sleep

SLEEP_SECOND = 1/ 10
for item in news:
	res = create_one_company_news(item)
	print(res)
	sleep(SLEEP_SECOND)
